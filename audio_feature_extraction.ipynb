# %% [markdown]
# # Audio Feature Extraction (finished)
#
# This notebook converts any `.m4a` files (if present) to `.wav` using `ffmpeg` (if installed), then extracts audio features (MFCCs, spectral, energy, chroma, contrast, tempo) for each file and saves per-person CSVs and a merged CSV under `data/processed/`.
#
# Instructions: run cells top-to-bottom. If you don't have `ffmpeg` installed on Windows, install via Chocolatey (`choco install ffmpeg`) or download a build and add to PATH.

# %%
# %pip install librosa soundfile resampy audioread numpy pandas matplotlib --quiet

# %%
import os
import glob
import shutil
import subprocess
import time
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import librosa
import librosa.display
from pathlib import Path
from scipy.io.wavfile import write
from IPython.display import Audio, display
print('Imports OK')
# Out:
# Imports OK

# %%
# Configuration - set your name/folders here
YOUR_NAME = 'Kerie'
AUDIO_FOLDER = os.path.abspath(f'audio_data/{YOUR_NAME}')
AUGMENTED_FOLDER = os.path.abspath(f'augmented_audio/{YOUR_NAME}')
OUTPUT_DIR = os.path.abspath('features_audio')
MERGED_OUTPUT = os.path.abspath(os.path.join(OUTPUT_DIR, 'audio_features_all.csv'))
os.makedirs(OUTPUT_DIR, exist_ok=True)
print('Configuration:')
print('  YOUR_NAME ->', YOUR_NAME)
print('  AUDIO_FOLDER ->', AUDIO_FOLDER)
print('  AUGMENTED_FOLDER ->', AUGMENTED_FOLDER)
print('  OUTPUT_DIR ->', OUTPUT_DIR)
print('  MERGED_OUTPUT ->', MERGED_OUTPUT)
# Out:
# Configuration:
#   YOUR_NAME -> Kerie
#   AUDIO_FOLDER -> c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie
#   AUGMENTED_FOLDER -> c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie
#   OUTPUT_DIR -> c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio
#   MERGED_OUTPUT -> c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\data\processed\audio_features_all.csv

# %% [markdown]
# ## Diagnostics: check folders and files
# Run this cell to confirm where files are and whether any .wav/.m4a files already exist.

# %%
print('Notebook cwd:', os.getcwd())
print('AUDIO_FOLDER exists:', os.path.exists(AUDIO_FOLDER))
if os.path.exists(AUDIO_FOLDER):
    for fname in sorted(os.listdir(AUDIO_FOLDER)):
        full = os.path.join(AUDIO_FOLDER, fname)
        try:
            size = os.path.getsize(full)
            mtime = time.ctime(os.path.getmtime(full))
        except Exception:
            size = '<err>'
            mtime = '<err>'
        print(f'  - {fname} | size={size} | mtime={mtime} | abs={os.path.abspath(full)}')
else:
    print('  (AUDIO_FOLDER not found)')

print('Recursive search for .wav and .m4a in repo:')
wav_files = glob.glob('**/*.wav', recursive=True)
m4a_files = glob.glob('**/*.m4a', recursive=True)
print('  .wav found:', len(wav_files))
for w in sorted(wav_files)[:50]:
    print('   -', os.path.abspath(w))
print('  .m4a found:', len(m4a_files))
for m in sorted(m4a_files)[:50]:
    print('   -', os.path.abspath(m))
# Out:
# Notebook cwd: c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing
# AUDIO_FOLDER exists: True
#   - Approve 1.wav | size=262222 | mtime=Wed Nov 12 19:22:33 2025 | abs=c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\Approve 1.wav
#   - Approve 2.wav | size=211022 | mtime=Wed Nov 12 19:22:40 2025 | abs=c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\Approve 2.wav
#   - CT1.wav | size=231502 | mtime=Wed Nov 12 19:21:35 2025 | abs=c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\CT1.wav
#   - CT2.wav | size=237646 | mtime=Wed Nov 12 19:22:47 2025 | abs=c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\CT2.wav
# Recursive search for .wav and .m4a in repo:
#   .wav found: 82
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_noise.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_pitch_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_time_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_time_slow.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_volume_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_volume_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_noise.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_pitch_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_time_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_time_slow.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_volume_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_volume_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\original\confirm_transaction.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\original\yes_approve.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\Approve 1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\Approve2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\CT1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\CT2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\Approve 1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\Approve 2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\CT1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\CT2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_1_noise.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_1_pitch.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_1_stretch.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_2_noise.wav
#   .m4a found: 0
#   .wav found: 82
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_noise.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_pitch_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_time_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_time_slow.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_volume_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_aug_volume_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_confirm_transaction_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_noise.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_pitch_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_time_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_time_slow.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_volume_down.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_aug_volume_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented\Fidel_yes_approve_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\original\confirm_transaction.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\original\yes_approve.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\Approve 1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\Approve2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\CT1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Irais\CT2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\Approve 1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\Approve 2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\CT1.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio_data\Kerie\CT2.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_1_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_confirm_transaction_2_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_1_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_fast.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_loud.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_noisy.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_original.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais\Irais_yes_approve_2_pitch_up.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_1_noise.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_1_pitch.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_1_stretch.wav
#    - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie\Kerie_confirm_transaction_2_noise.wav
#   .m4a found: 0

# %% [markdown]
# ## ffmpeg check & conversion
# This cell will convert `.m4a` files inside `AUDIO_FOLDER` to `.wav` using `ffmpeg` if it's available. It writes the `.wav` to the same folder with the same base name.

# %%
def ffmpeg_available():
    return shutil.which('ffmpeg') is not None

def convert_m4a_to_wav(input_path, output_path, show_output=False):
    ff = shutil.which('ffmpeg')
    if ff is None:
        print('ffmpeg not found on PATH; please install it to convert .m4a files')
        return False
    cmd = [ff, '-hide_banner', '-y', '-i', input_path, '-acodec', 'pcm_s16le', '-ar', '44100', output_path]
    print('Running:', ' '.join(cmd))
    proc = subprocess.run(cmd, capture_output=True, text=True)
    if proc.returncode != 0 or show_output:
        print('ffmpeg stdout:', proc.stdout)
        print('ffmpeg stderr:', proc.stderr)
    if proc.returncode == 0 and os.path.exists(output_path) and os.path.getsize(output_path) > 0:
        return True
    return False

# Perform conversion only if AUDIO_FOLDER exists
if os.path.exists(AUDIO_FOLDER):
    m4as = [f for f in os.listdir(AUDIO_FOLDER) if f.lower().endswith('.m4a')]
    print('Found', len(m4as), '.m4a files')
    conv = 0; skip = 0; fail = 0
    for fname in m4as:
        inp = os.path.join(AUDIO_FOLDER, fname)
        out = os.path.join(AUDIO_FOLDER, os.path.splitext(fname)[0] + '.wav')
        if os.path.exists(out) and os.path.getsize(out) > 0:
            print('Skipping, wav exists:', out)
            skip += 1
            continue
        ok = convert_m4a_to_wav(inp, out, show_output=True)
        if ok:
            print('Converted ->', out)
            conv += 1
        else:
            print('Failed to convert', inp)
            fail += 1
    print(f'Conversion summary: converted={conv}, skipped={skip}, failed={fail}')
else:
    print('AUDIO_FOLDER not found; skipping conversion')
# Out:
# Found 0 .m4a files
# Conversion summary: converted=0, skipped=0, failed=0

# %% [markdown]
# ## AudioFeatureExtractor class
# The class below extracts features for a single file and helper functions for phrase/person detection.

# %%
class AudioFeatureExtractor:
    """Extract audio features from wav files for voice verification."""
    def __init__(self, remove_silence: bool = False, sample_rate: int = 22050):
        self.remove_silence = remove_silence
        self.sample_rate = sample_rate

    def remove_silence_from_audio(self, y, sr):
        y_trimmed, _ = librosa.effects.trim(y, top_db=20)
        return y_trimmed

    def extract_features(self, audio_path):
        try:
            y, sr = librosa.load(audio_path, sr=self.sample_rate)
            if self.remove_silence:
                y = self.remove_silence_from_audio(y, sr)
            features = {}
            mfccs = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=13)
            mfcc_mean = np.mean(mfccs, axis=1)
            mfcc_std = np.std(mfccs, axis=1)
            for i in range(13):
                features[f'mfcc_{i}_mean'] = float(mfcc_mean[i])
                features[f'mfcc_{i}_std'] = float(mfcc_std[i])
            # spectral and energy features
            features['spectral_centroid_mean'] = float(np.mean(librosa.feature.spectral_centroid(y=y, sr=sr)))
            features['spectral_rolloff_mean'] = float(np.mean(librosa.feature.spectral_rolloff(y=y, sr=sr)))
            features['rms_energy_mean'] = float(np.mean(librosa.feature.rms(y=y)))
            features['zcr_mean'] = float(np.mean(librosa.feature.zero_crossing_rate(y)))
            chroma = librosa.feature.chroma_stft(y=y, sr=sr)
            for i, c in enumerate(np.mean(chroma, axis=1)):
                features[f'chroma_{i}_mean'] = float(c)
            try:
                tempo, _ = librosa.beat.beat_track(y=y, sr=sr)
                features['tempo'] = float(tempo)
            except Exception:
                features['tempo'] = 0.0
            return features
        except Exception as e:
            print('Error extracting', audio_path, e)
            return None

def _extract_phrase_from_filename(filename):
    ln = filename.lower()
    if 'approve' in ln or 'yes' in ln:
        return 'approve'
    if 'confirm' in ln or 'ct' in ln:
        return 'confirm_transaction'
    return 'unknown'

def _extract_person_from_path(filepath):
    parts = Path(filepath).parts
    for candidate in ['Fidel','Kerie','Irais']:
        if candidate.lower() in filepath.lower():
            return candidate
    for p in parts:
        if p in ['Fidel','Kerie','Irais']:
            return p
    return 'Unknown'

print('Feature extractor ready')
# Out:
# Feature extractor ready

# %% [markdown]
# ## Process folders and extract features
# The cell below searches folders for each person, extracts features and saves per-person CSVs and a merged CSV.`

# %%
# Folder mappings (adjust if your project differs)
folder_mappings = {
    'Fidel': [os.path.join('.', 'audio', 'augmented')],
    'Kerie': [os.path.join('.', 'augmented_audio', 'Kerie')],
    'Irais': [os.path.join('.', 'augmented_audio', 'Irais')]
}

extractor = AudioFeatureExtractor()
all_features = {}
total_processed = 0
for person, folders in folder_mappings.items():
    rows = []
    for folder in folders:
        folder = os.path.abspath(folder)
        if not os.path.exists(folder):
            print('Folder missing, skipping:', folder)
            continue
        wavs = [os.path.join(folder, f) for f in os.listdir(folder) if f.lower().endswith('.wav')]
        print(f'Found {len(wavs)} wav(s) in {folder}')
        for p in wavs:
            feats = extractor.extract_features(p)
            if feats is None:
                continue
            feats['person'] = person
            feats['audio_path'] = os.path.abspath(p)
            feats['audio_name'] = os.path.basename(p)
            feats['phrase'] = _extract_phrase_from_filename(os.path.basename(p))
            rows.append(feats)
    if rows:
        df_person = pd.DataFrame(rows)
        out_file = os.path.join(OUTPUT_DIR, f'{person}_audio_features.csv')
        df_person.to_csv(out_file, index=False)
        all_features[person] = df_person
        total_processed += len(df_person)
        print(f'Wrote {out_file} ({len(df_person)} rows)')

# Merge and save
if all_features:
    merged = pd.concat(all_features.values(), ignore_index=True)
    meta_cols = ['person', 'audio_path', 'audio_name', 'phrase']
    for c in meta_cols:
        if c not in merged.columns:
            merged[c] = ''
    cols = meta_cols + [c for c in merged.columns if c not in meta_cols]
    merged = merged[cols]
    merged.to_csv(MERGED_OUTPUT, index=False)
    print(f'Merged features saved to {MERGED_OUTPUT} (rows={len(merged)})')
    # Save feature column names (exclude metadata) for model usage
    feature_cols = [c for c in merged.columns if c not in meta_cols]
    cols_file = os.path.join(OUTPUT_DIR, 'feature_columns.txt')
    with open(cols_file, 'w', encoding='utf-8') as fh:
        fh.write('\n'.join(feature_cols))
    print(f'Feature columns saved to {cols_file} (count={len(feature_cols)})')
else:
    print('No features extracted. Check that folders contain .wav files or run the conversion cell first.')
# Out:
# Found 16 wav(s) in c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\audio\augmented
# Wrote c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Fidel_audio_features.csv (16 rows)
# Found 12 wav(s) in c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie
# Wrote c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Fidel_audio_features.csv (16 rows)
# Found 12 wav(s) in c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Kerie
# Wrote c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Kerie_audio_features.csv (12 rows)
# Found 20 wav(s) in c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais
# Wrote c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Kerie_audio_features.csv (12 rows)
# Found 20 wav(s) in c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\augmented_audio\Irais
# Wrote c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Irais_audio_features.csv (20 rows)
# Merged features saved to c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\data\processed\audio_features_all.csv (rows=48)
# Wrote c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Irais_audio_features.csv (20 rows)
# Merged features saved to c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\data\processed\audio_features_all.csv (rows=48)

# %% [markdown]
# ## Quick checks
# List the newly created feature files and show a sample row from the merged CSV (if exists).

# %%
print('Files in', OUTPUT_DIR)
if os.path.exists(OUTPUT_DIR):
    for f in sorted(os.listdir(OUTPUT_DIR)):
        print(' -', os.path.join(OUTPUT_DIR, f))

if os.path.exists(MERGED_OUTPUT):
    dfm = pd.read_csv(MERGED_OUTPUT)
    print('\nMerged CSV path:', MERGED_OUTPUT, 'rows:', len(dfm))
    display(dfm.head(5))
else:
    print('Merged CSV not found:', MERGED_OUTPUT)
# Out:
# Files in c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio
#  - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Fidel_audio_features.csv
#  - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Irais_audio_features.csv
#  - c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\Formative-2-Data-Preprocessing\features_audio\Kerie_audio_features.csv
# Merged CSV sample rows: 48
#     mfcc_0_mean  mfcc_0_std  mfcc_1_mean  mfcc_1_std  mfcc_2_mean  mfcc_2_std  \
# 0   -323.525208   43.516697    11.343247   36.618992     5.898495   16.233978
# 1   -612.330200  207.960693    44.700008   59.605667    21.499029   25.132103
# 2   -602.238098  193.085983    41.418762   59.347988    15.623070   26.032578
# 3   -605.934204  205.846344    42.851822   58.401211    21.193609   24.867525
# 4   -609.548828  199.078125    40.294361   60.046928    19.327871   25.396095
# 5   -645.265198  209.979218    47.242092   60.702068    21.397139   25.906296
# 6   -538.058838  210.625900    46.858982   60.889812    21.305552   25.988304
# 7   -578.002747  210.714050    46.788502   60.920109    21.252876   25.999146
# 8   -330.218170   31.177803     0.726351   36.349045    13.564811   20.735401
# 9   -582.271667  157.260544    23.571775   81.554268    29.482561   26.884964
# 10  -591.672302  152.340836    29.462919   79.320503    28.175154   32.867714
# 4        0.389968       0.374686        0.367824        0.374536   60.092660
# 5        0.396865       0.379882        0.373591        0.392854   75.999540
# 6        0.392578       0.375115        0.371131        0.391141   75.999540
# 7        0.390816       0.375584        0.371954        0.393565   75.999540
# 8        0.598400       0.632485        0.567598        0.554248  112.347147
# 9        0.367018       0.363716        0.445481        0.544423  135.999178
# 10       0.258490       0.347478        0.440500        0.440987  112.347147
# 11       0.423727       0.435506        0.363347        0.337311  135.999178
# 12       0.409673       0.399480        0.360424        0.316422  129.199219
# 13       0.442893       0.451431        0.397952        0.360734  143.554688
# 14       0.450681       0.449453        0.397594        0.366541  143.554688
# 15       0.449238       0.443608        0.392246        0.363206  143.554688
# 16       0.543187       0.635522        0.687492        0.559480  129.199219
# 17       0.423501       0.399839        0.435694        0.534985  129.199219
# 18       0.395436       0.483306        0.592834        0.540716  117.453835
# 19       0.556845       0.644011        0.596269        0.537570  129.199219
# 20       0.459632       0.410594        0.380569        0.501815   80.749512
# 21       0.458273       0.575605        0.564671        0.478616   95.703125
# 22       0.649419       0.720940        0.663338        0.629418  143.554688
# 23       0.395192       0.470124        0.658919        0.597302  135.999178
# 24       0.501233       0.624925        0.528369        0.452818  107.666016
# 25       0.630528       0.677234        0.590994        0.554200  129.199219
# 26       0.333736       0.286664        0.393868        0.585551  129.199219
# 27       0.555076       0.581181        0.423144        0.376606  151.999081
# 28       0.576954       0.606612        0.493919        0.369709  161.499023
# 29       0.609102       0.629871        0.542210        0.414378  135.999178
# 30       0.715895       0.703929        0.617231        0.543131  129.199219
# 31       0.608917       0.629656        0.541971        0.414260  135.999178
# 32       0.419189       0.545205        0.626296        0.565727  129.199219
# 33       0.598815       0.568971        0.492900        0.416835  151.999081
# 34       0.623280       0.557618        0.466141        0.421379  129.199219
# 35       0.691240       0.658101        0.589909        0.581411  129.199219
# 36       0.623241       0.557534        0.466150        0.421196  129.199219
# 37       0.415171       0.594883        0.645259        0.579266  129.199219
# 38       0.593095       0.553239        0.452804        0.384522   95.703125
# 39       0.630927       0.554956        0.459158        0.402313   78.302557
# 40       0.678848       0.591312        0.558446        0.575868  107.666016
# 41       0.630540       0.554783        0.459053        0.402209   78.302557
# 42       0.418482       0.627685        0.601314        0.531232   80.749512
# 43       0.653471       0.681795        0.561206        0.456156  135.999178
# 44       0.623854       0.691546        0.563611        0.415457  107.666016
# 45       0.722515       0.666159        0.632270        0.572271  112.347147
# 46       0.624098       0.691739        0.563679        0.415526  107.666016
# 47       0.487382       0.582052        0.618964        0.637530   95.703125
#
#     person                                         audio_path  \
# 0    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 1    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 2    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 3    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 4    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 5    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 6    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 7    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 8    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 9    Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 10   Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 11   Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 12   Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 13   Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 14   Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 15   Fidel  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 16   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 17   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 18   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 19   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 20   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 21   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 22   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 23   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 24   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 25   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 26   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 27   Kerie  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 28   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 29   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 30   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 31   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 32   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 33   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 34   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 35   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 36   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 37   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 38   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 39   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 40   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 41   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 42   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 43   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 44   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 45   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 46   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
# 47   Irais  c:\Users\LENOVO\Documents\KERIE\ML_FORMATIVE2\...
#
#                                        audio_name       phrase
# 0         Fidel_confirm_transaction_aug_noise.wav   confirm_tx
# 1    Fidel_confirm_transaction_aug_pitch_down.wav   confirm_tx
# 2      Fidel_confirm_transaction_aug_pitch_up.wav   confirm_tx
# 3     Fidel_confirm_transaction_aug_time_fast.wav   confirm_tx
# 4     Fidel_confirm_transaction_aug_time_slow.wav   confirm_tx
# 5   Fidel_confirm_transaction_aug_volume_down.wav   confirm_tx
# 6     Fidel_confirm_transaction_aug_volume_up.wav   confirm_tx
# 7          Fidel_confirm_transaction_original.wav   confirm_tx
# 8                 Fidel_yes_approve_aug_noise.wav  approve_yes
# 9            Fidel_yes_approve_aug_pitch_down.wav  approve_yes
# 10             Fidel_yes_approve_aug_pitch_up.wav  approve_yes
# 11            Fidel_yes_approve_aug_time_fast.wav  approve_yes
# 12            Fidel_yes_approve_aug_time_slow.wav  approve_yes
# 13          Fidel_yes_approve_aug_volume_down.wav  approve_yes
# 14            Fidel_yes_approve_aug_volume_up.wav  approve_yes
# 15                 Fidel_yes_approve_original.wav  approve_yes
# 16          Kerie_confirm_transaction_1_noise.wav   confirm_tx
# 17          Kerie_confirm_transaction_1_pitch.wav   confirm_tx
# 18        Kerie_confirm_transaction_1_stretch.wav   confirm_tx
# 19          Kerie_confirm_transaction_2_noise.wav   confirm_tx
# 20          Kerie_confirm_transaction_2_pitch.wav   confirm_tx
# 21        Kerie_confirm_transaction_2_stretch.wav   confirm_tx
# 22                  Kerie_yes_approve_1_noise.wav  approve_yes
# 23                  Kerie_yes_approve_1_pitch.wav  approve_yes
# 24                Kerie_yes_approve_1_stretch.wav  approve_yes
# 25                  Kerie_yes_approve_2_noise.wav  approve_yes
# 26                  Kerie_yes_approve_2_pitch.wav  approve_yes
# 27                Kerie_yes_approve_2_stretch.wav  approve_yes
# 28           Irais_confirm_transaction_1_fast.wav   confirm_tx
# 29           Irais_confirm_transaction_1_loud.wav   confirm_tx
# 30          Irais_confirm_transaction_1_noisy.wav   confirm_tx
# 31       Irais_confirm_transaction_1_original.wav   confirm_tx
# 32       Irais_confirm_transaction_1_pitch_up.wav   confirm_tx
# 33           Irais_confirm_transaction_2_fast.wav   confirm_tx
# 34           Irais_confirm_transaction_2_loud.wav   confirm_tx
# 35          Irais_confirm_transaction_2_noisy.wav   confirm_tx
# 36       Irais_confirm_transaction_2_original.wav   confirm_tx
# 37       Irais_confirm_transaction_2_pitch_up.wav   confirm_tx
# 38                   Irais_yes_approve_1_fast.wav  approve_yes
# 39                   Irais_yes_approve_1_loud.wav  approve_yes
# 40                  Irais_yes_approve_1_noisy.wav  approve_yes
# 41               Irais_yes_approve_1_original.wav  approve_yes
# 42               Irais_yes_approve_1_pitch_up.wav  approve_yes
# 43                   Irais_yes_approve_2_fast.wav  approve_yes
# 44                   Irais_yes_approve_2_loud.wav  approve_yes
# 45                  Irais_yes_approve_2_noisy.wav  approve_yes
# 46               Irais_yes_approve_2_original.wav  approve_yes
# 47               Irais_yes_approve_2_pitch_up.wav  approve_yes
#
# [48 rows x 47 columns]
